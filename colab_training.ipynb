# %% [markdown]
# По состоянию на 2022-07-17 запуск команды python3 hypermodel.py не влезает по памяти в бесплатный гугл колаб.

# %%
from google.colab import drive
GOOGLE_DRIVE_MOUNT = "/content/gdrive"
drive.mount(GOOGLE_DRIVE_MOUNT)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My\ Drive/model_training/DL2021_HI-C
# Out:
# /content/gdrive/My Drive/model_training/DL2021_HI-C

# %%
# !python3 -m pip install -r requirements_new.txt

# %%
# !python3 hypermodel.py
# Out:
# tcmalloc: large alloc 9596002304 bytes == 0x7fdb0608a000 @  0x7fde355671e7 0x7fddc4e1e0ce 0x7fddc4e75e57 0x7fddc4e76a6f 0x7fddc4f1cc5d 0x593835 0x548c51 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x51566f 0x549e0e 0x593fce 0x548ae9 0x5127f1 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7fde35164c87 0x5b621a
# ^C

# %%
# !python3 hypermodel_graph.py
# Out:
# Traceback (most recent call last):
#   File "hypermodel_graph.py", line 286, in <module>
#     model = HyperModel()
#   File "hypermodel_graph.py", line 52, in __init__
#     self.vehicle = GAN_Model() #Dummy()
#   File "/content/gdrive/MyDrive/model_training/DL2021_HI-C/vehicle/Models/VEHiCLE_Module.py", line 36, in __init__
#     self.vae             = vl.VaeLoss(self.vae_yaml, self.vae_weight)
#   File "/content/gdrive/MyDrive/model_training/DL2021_HI-C/vehicle/Utils/loss/vae_loss.py", line 15, in __init__
#     hparams = yaml.load(op)
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
# !rm -rf */*/*/__pycache__/
